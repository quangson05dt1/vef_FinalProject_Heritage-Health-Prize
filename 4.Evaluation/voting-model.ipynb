# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
from sklearn import ensemble
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import pandas as pd
import math

# %%
df = pd.read_csv('../2.Feature Engineering/new data/modelling_set.csv')
df.describe()
# Out:
#            MemberID  LabCount_total   LabCount_max   LabCount_min  \
# count  2.184150e+05   218415.000000  218415.000000  218415.000000
# mean   4.993458e+07        6.471827       3.829439       2.181860
# std    2.892479e+07        7.734678       3.440373       2.507408
# min    4.000000e+00        0.000000       0.000000       0.000000
# 25%    2.478774e+07        0.000000       0.000000       0.000000
# 50%    4.993677e+07        4.000000       4.000000       1.000000
# 75%    7.515525e+07       10.000000       7.000000       3.000000
# max    9.999882e+07      111.000000      10.000000      10.000000
#
#         LabCount_ave  LabCount_months   LabCount_std  DrugCount_total  \
# count  218415.000000    218415.000000  218415.000000    218415.000000
# mean        2.918800         1.655033       0.578166        10.387318
# std         2.676663         1.906704       1.683426        15.721582
# min         0.000000         0.000000      -1.000000         0.000000
# 25%         0.000000         0.000000      -1.000000         0.000000
# 50%         2.666667         1.000000       0.000000         3.000000
# 75%         5.000000         2.000000       1.527525        14.000000
# max        10.000000        12.000000       6.363961        84.000000
#
#        DrugCount_max  DrugCount_min  ...  ProcedureGroup_Count_SO  \
# count  218415.000000  218415.000000  ...            218415.000000
# mean        2.193531       0.962237  ...                 0.001699
# std         2.271990       1.057978  ...                 0.047286
# min         0.000000       0.000000  ...                 0.000000
# 25%         0.000000       0.000000  ...                 0.000000
# 50%         2.000000       1.000000  ...                 0.000000
# 75%         4.000000       1.000000  ...                 0.000000
# max         7.000000       7.000000  ...                 4.000000
#
#        ProcedureGroup_Count_SMCD  AgeAtFirstClaim           Male  \
# count              218415.000000    218415.000000  218415.000000
# mean                    0.015457        47.750155       0.363524
# std                     0.262061        23.238375       0.481015
# min                     0.000000         5.000000       0.000000
# 25%                     0.000000        35.000000       0.000000
# 50%                     0.000000        45.000000       0.000000
# 75%                     0.000000        65.000000       1.000000
# max                    23.000000        80.000000       1.000000
#
#               Female        MissSex   MissAge  ClaimsTruncated         TARGET  \
# count  218415.000000  218415.000000  218415.0    218415.000000  147473.000000
# mean        0.448078       0.188398       0.0         0.054863       0.452951
# std         0.497298       0.391031       0.0         0.227714       1.573818
# min         0.000000       0.000000       0.0         0.000000       0.000000
# 25%         0.000000       0.000000       0.0         0.000000       0.000000
# 50%         0.000000       0.000000       0.0         0.000000       0.000000
# 75%         1.000000       0.000000       0.0         0.000000       0.000000
# max         1.000000       1.000000       0.0         1.000000      15.000000
#
#             trainset
# count  218415.000000
# mean        0.675196
# std         0.468303
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 144 columns]

# %%
df_train = df[df['trainset']==1]
df_target = df[df['trainset']==0]
df_train.describe()
# Out:
#            MemberID  LabCount_total   LabCount_max   LabCount_min  \
# count  1.474730e+05   147473.000000  147473.000000  147473.000000
# mean   4.994386e+07        6.391699       3.817465       2.179124
# std    2.892040e+07        7.555581       3.428776       2.503624
# min    4.000000e+00        0.000000       0.000000       0.000000
# 25%    2.481269e+07        0.000000       0.000000       0.000000
# 50%    4.993194e+07        4.000000       4.000000       1.000000
# 75%    7.516935e+07       10.000000       6.000000       3.000000
# max    9.999882e+07       94.000000      10.000000      10.000000
#
#         LabCount_ave  LabCount_months   LabCount_std  DrugCount_total  \
# count  147473.000000    147473.000000  147473.000000    147473.000000
# mean        2.910567         1.644898       0.576201        10.409309
# std         2.669596         1.895061       1.683874        15.681812
# min         0.000000         0.000000      -1.000000         0.000000
# 25%         0.000000         0.000000      -1.000000         0.000000
# 50%         2.666667         1.000000       0.000000         3.000000
# 75%         4.800000         2.000000       1.527525        15.000000
# max        10.000000        12.000000       6.363961        84.000000
#
#        DrugCount_max  DrugCount_min  ...  ProcedureGroup_Count_SO  \
# count  147473.000000  147473.000000  ...            147473.000000
# mean        2.190754       0.959057  ...                 0.001478
# std         2.261954       1.043603  ...                 0.043549
# min         0.000000       0.000000  ...                 0.000000
# 25%         0.000000       0.000000  ...                 0.000000
# 50%         2.000000       1.000000  ...                 0.000000
# 75%         4.000000       1.000000  ...                 0.000000
# max         7.000000       7.000000  ...                 4.000000
#
#        ProcedureGroup_Count_SMCD  AgeAtFirstClaim           Male  \
# count              147473.000000    147473.000000  147473.000000
# mean                    0.015949        47.884731       0.362907
# std                     0.270775        23.342989       0.480840
# min                     0.000000         5.000000       0.000000
# 25%                     0.000000        35.000000       0.000000
# 50%                     0.000000        45.000000       0.000000
# 75%                     0.000000        65.000000       1.000000
# max                    23.000000        80.000000       1.000000
#
#               Female        MissSex   MissAge  ClaimsTruncated         TARGET  \
# count  147473.000000  147473.000000  147473.0    147473.000000  147473.000000
# mean        0.446678       0.190415       0.0         0.054349       0.452951
# std         0.497150       0.392629       0.0         0.226706       1.573818
# min         0.000000       0.000000       0.0         0.000000       0.000000
# 25%         0.000000       0.000000       0.0         0.000000       0.000000
# 50%         0.000000       0.000000       0.0         0.000000       0.000000
# 75%         1.000000       0.000000       0.0         0.000000       0.000000
# max         1.000000       1.000000       0.0         1.000000      15.000000
#
#        trainset
# count  147473.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
#
# [8 rows x 144 columns]

# %%
#Count missing data
def count_missing(df):   
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    print(missing_data.head(20))
    return missing_data

count_missing(df_train)
# Out:
#                                          Total  Percent
# trainset                                     0      0.0
# PlaceSvc_Count_Unknown                       0      0.0
# Specialty_Count_Surgery                      0      0.0
# CharlsonIndex_range                          0      0.0
# DSFS_range                                   0      0.0
# no_PrimaryConditionGroup_PlaceSvc            0      0.0
# no_ProcedureGroup_PrimaryConditionGroup      0      0.0
# no_ProcedureGroup_Specialty                  0      0.0
# no_PrimaryConditionGroup_Specialty           0      0.0
# CharlsonIndex_std                            0      0.0
# CharlsonIndex_ave                            0      0.0
# CharlsonIndex_min                            0      0.0
# CharlsonIndex_max                            0      0.0
# CharlsonIndex_sum                            0      0.0
# DSFS_std                                     0      0.0
# DSFS_ave                                     0      0.0
# DSFS_min                                     0      0.0
# Specialty_Count_Internal                     0      0.0
# Specialty_Count_Laboratory                   0      0.0
# Specialty_Count_Pediatrics                   0      0.0
#                                      Total  Percent
# trainset                                 0      0.0
# PlaceSvc_Count_Unknown                   0      0.0
# Specialty_Count_Surgery                  0      0.0
# CharlsonIndex_range                      0      0.0
# DSFS_range                               0      0.0
# ...                                    ...      ...
# PrimaryConditionGroup_Count_CANCRB       0      0.0
# PrimaryConditionGroup_Count_SKNAUT       0      0.0
# PrimaryConditionGroup_Count_HIPFX        0      0.0
# PrimaryConditionGroup_Count_GIBLEED      0      0.0
# Year                                     0      0.0
#
# [145 rows x 2 columns]

# %%
m = (df_train.columns != 'TARGET') & (df_train.columns != 'MemberID') & (df_train.columns != 'Year') & (df_train.columns != 'trainset')
X = df_train.loc[:, m]
y = df_train['TARGET']
y.describe()
# Out:
# count    147473.000000
# mean          0.452951
# std           1.573818
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          15.000000
# Name: TARGET, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler = MinMaxScaler(feature_range=(0,1)).fit(X)
#scaler = StandardScaler().fit(X)


new_X = scaler.transform(X)
X_train, X_test, y_train, y_test = train_test_split(new_X, y, test_size=0.3, random_state=123)

# %%
def eval(model, X_test, y_test):
    pred_y = model.predict(X_test) # your predicted y values
    # The root mean square logarithmic error
    pred_y = pred_y.clip(min=0)
    pred_y = pred_y.clip(max=15)
    pred_y = pred_y.astype(int)
    msle = np.mean( (np.log(pred_y + 1) - np.log(y_test + 1)) ** 2)
    rmsle = math.sqrt(msle)
    print ("RMSLE: %.2f" % rmsle)
    from sklearn.metrics import r2_score
    r2 = r2_score(y_test,pred_y)
    print ("R2 value: %.2f" % r2)
    from sklearn.metrics import mean_squared_log_error
    err = math.sqrt(mean_squared_log_error(y_test,pred_y))
    print ("Err value: %.2f" % err)
    return rmsle, r2

# %%
clf1= ensemble.GradientBoostingRegressor(
                                          n_estimators=1000,
                                          learning_rate= 0.00523960135300263,
                                          max_depth = 7,
                                          min_samples_leaf=100,
                                          verbose =1)
clf1.fit(X_train,y_train)
eval(clf1,X_test,y_test)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           2.4095           30.07m
#          2           2.4071           29.79m
#          3           2.4048           29.63m
#          4           2.4026           29.49m
#          5           2.4004           29.37m
#          6           2.3982           29.34m
#          7           2.3960           29.30m
#          8           2.3938           29.53m
#          9           2.3917           29.63m
#         10           2.3895           29.61m
#         20           2.3693           29.31m
#         30           2.3506           28.85m
#         40           2.3331           28.54m
#         50           2.3171           28.53m
#         60           2.3023           28.28m
#         70           2.2887           28.03m
#         80           2.2760           27.75m
#         90           2.2644           27.39m
#        100           2.2534           27.05m
#        200           2.1750           24.10m
#        300           2.1303           21.10m
#        400           2.0996           18.16m
#        500           2.0770           15.25m
#        600           2.0611           12.25m
#        700           2.0487            9.21m
#        800           2.0377            6.15m
#        900           2.0288            3.08m
#       1000           2.0214            0.00s
# RMSLE: 0.49
# R2 value: 0.02
# Err value: 0.49
# (0.49282791998478126, 0.016498064659897227)

# %%
from sklearn import linear_model

clf2= linear_model.LinearRegression()
clf2.fit(X_train,y_train)
eval(clf2,X_test, y_test)
# Out:
# RMSLE: 0.50
# R2 value: 0.00
# Err value: 0.50
# (0.4973750668347952, 0.00395234419702728)

# %%
from sklearn.neural_network import MLPRegressor
clf3 = MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
        beta_2=0.999, early_stopping=False, epsilon=1e-08,
        hidden_layer_sizes=1, learning_rate='constant',
        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
        nesterovs_momentum=True, power_t=0.5, random_state=None,
        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
        verbose=1, warm_start=False)
clf3.fit(X_train,y_train)
eval(clf3, X_test, y_test)
# Out:
# Iteration 1, loss = 1.19474817
# Iteration 2, loss = 1.16065796
# Iteration 3, loss = 1.14688926
# Iteration 4, loss = 1.13787221
# Iteration 5, loss = 1.13206559
# Iteration 6, loss = 1.12825190
# Iteration 7, loss = 1.12540233
# Iteration 8, loss = 1.12358812
# Iteration 9, loss = 1.12204076
# Iteration 10, loss = 1.12099387
# Iteration 11, loss = 1.12046121
# Iteration 12, loss = 1.11925851
# Iteration 13, loss = 1.11855899
# Iteration 14, loss = 1.11817113
# Iteration 15, loss = 1.11732267
# Iteration 16, loss = 1.11709694
# Iteration 17, loss = 1.11672072
# Iteration 18, loss = 1.11630917
# Iteration 19, loss = 1.11573084
# Iteration 20, loss = 1.11538680
# Iteration 21, loss = 1.11516617
# Iteration 22, loss = 1.11457556
# Iteration 23, loss = 1.11442676
# Iteration 24, loss = 1.11460611
# Iteration 25, loss = 1.11428881
# Iteration 26, loss = 1.11389422
# Iteration 27, loss = 1.11354151
# Iteration 28, loss = 1.11365577
# Iteration 29, loss = 1.11330331
# Iteration 30, loss = 1.11320867
# Iteration 31, loss = 1.11287352
# Iteration 32, loss = 1.11345446
# Iteration 33, loss = 1.11283684
# Iteration 34, loss = 1.11258203
# Iteration 35, loss = 1.11265252
# Iteration 36, loss = 1.11269061
# Iteration 37, loss = 1.11262149
# Iteration 38, loss = 1.11218227
# Iteration 39, loss = 1.11214656
# Iteration 40, loss = 1.11225984
# Iteration 41, loss = 1.11188543
# Iteration 42, loss = 1.11174051
# Iteration 43, loss = 1.11186962
# Iteration 44, loss = 1.11164554
# Iteration 45, loss = 1.11151808
# Iteration 46, loss = 1.11130604
# Iteration 47, loss = 1.11200813
# Iteration 48, loss = 1.11151885
# Iteration 49, loss = 1.11164802
# Iteration 50, loss = 1.11145699
# Iteration 51, loss = 1.11143157
# Iteration 52, loss = 1.11169201
# Iteration 53, loss = 1.11150819
# Iteration 54, loss = 1.11130403
# Iteration 55, loss = 1.11130642
# Iteration 56, loss = 1.11150709
# Iteration 57, loss = 1.11083357
# Iteration 58, loss = 1.11137120
# Iteration 59, loss = 1.11065456
# Iteration 60, loss = 1.11092969
# Iteration 61, loss = 1.11099254
# Iteration 62, loss = 1.11128406
# Iteration 63, loss = 1.11085074
# Iteration 64, loss = 1.11109564
# Iteration 65, loss = 1.11106782
# Iteration 66, loss = 1.11058058
# Iteration 67, loss = 1.11075427
# Iteration 68, loss = 1.11121367
# Iteration 69, loss = 1.11073683
# Iteration 70, loss = 1.11085439
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# RMSLE: 0.50
# R2 value: 0.01
# Err value: 0.50
# (0.49674135308441153, 0.010736835934658795)

# %%
clf4= ensemble.RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
            max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=5, min_samples_split=500,
            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=-1,
            oob_score=False, random_state=None, verbose=1, warm_start=False)
clf4.fit(X_train,y_train)


w4 = 0.4846
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:  6.4min finished

# %%
eval(clf4, X_test, y_test)
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 776 tasks      | elapsed:    0.3s
# RMSLE: 0.49
# R2 value: 0.01
# Err value: 0.49
# [Parallel(n_jobs=12)]: Done 1000 out of 1000 | elapsed:    0.4s finished
# (0.4931522108580743, 0.010057526876011247)

# %%
clf5 = linear_model.Ridge(alpha=0.304585534067427, copy_X=True, fit_intercept=True, max_iter=5000,
     normalize=False, tol=0.0001)
clf5.fit(X_train,y_train)

eval(clf5, X_test, y_test)
# Out:
# RMSLE: 0.50
# R2 value: 0.04
# Err value: 0.50
# (0.5008227464703024, 0.03714390073347551)

# %%
clfs=[('gbm',clf1),
       ('linear',clf2),
       ('mlp',clf3),
       ('rfr',clf4),
       ('ridge',clf5)]

#weights=[w1,w2,w3,w4,w5]

eclf = ensemble.VotingRegressor(estimators=clfs, verbose =1,n_jobs = -1)
eclf.fit(X_train,y_train)
# Out:
# VotingRegressor(estimators=[('gbm',
#                              GradientBoostingRegressor(learning_rate=0.00523960135300263,
#                                                        max_depth=7,
#                                                        min_samples_leaf=100,
#                                                        n_estimators=1000,
#                                                        verbose=1)),
#                             ('linear', LinearRegression()),
#                             ('mlp',
#                              MLPRegressor(hidden_layer_sizes=1, max_iter=1000,
#                                           verbose=1)),
#                             ('rfr',
#                              RandomForestRegressor(max_depth=10,
#                                                    min_samples_leaf=5,
#                                                    min_samples_split=500,
#                                                    n_estimators=1000, n_jobs=-1,
#                                                    verbose=1)),
#                             ('lasso',
#                              Ridge(alpha=0.304585534067427, max_iter=5000,
#                                    tol=0.0001))],
#                 n_jobs=-1, verbose=1)

# %%
m = (df_target.columns != 'TARGET') & (df_target.columns != 'MemberID') & (df_target.columns != 'Year') & (df_target.columns != 'trainset')
X_submit = df_target.loc[:, m]
y_submit = df_target['TARGET']
y_submit.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: TARGET, dtype: float64

# %%
count_missing(X_submit)
# Out:
#                                          Total  Percent
# ClaimsTruncated                              0      0.0
# no_PrimaryConditionGroup_Specialty           0      0.0
# Specialty_Count_Surgery                      0      0.0
# CharlsonIndex_range                          0      0.0
# DSFS_range                                   0      0.0
# no_PrimaryConditionGroup_PlaceSvc            0      0.0
# no_ProcedureGroup_PrimaryConditionGroup      0      0.0
# no_ProcedureGroup_Specialty                  0      0.0
# CharlsonIndex_std                            0      0.0
# Specialty_Count_Laboratory                   0      0.0
# CharlsonIndex_ave                            0      0.0
# CharlsonIndex_min                            0      0.0
# CharlsonIndex_max                            0      0.0
# CharlsonIndex_sum                            0      0.0
# DSFS_std                                     0      0.0
# DSFS_ave                                     0      0.0
# Specialty_Count_Internal                     0      0.0
# Specialty_Count_Pediatrics                   0      0.0
# PlaceSvc_Count_Unknown                       0      0.0
# Specialty_Count_Unknown                      0      0.0
#                                      Total  Percent
# ClaimsTruncated                          0      0.0
# no_PrimaryConditionGroup_Specialty       0      0.0
# Specialty_Count_Surgery                  0      0.0
# CharlsonIndex_range                      0      0.0
# DSFS_range                               0      0.0
# ...                                    ...      ...
# PrimaryConditionGroup_Count_ODaBNCA      0      0.0
# PrimaryConditionGroup_Count_HEMTOL       0      0.0
# PrimaryConditionGroup_Count_GYNECA       0      0.0
# PrimaryConditionGroup_Count_APPCHOL      0      0.0
# LabCount_total                           0      0.0
#
# [141 rows x 2 columns]

# %%
X_submit_scl = scaler.transform(X_submit)

# %%
submission = pd.DataFrame()
submission['MemberID'] = df_target['MemberID']
for i in range(0,5):
    y_pred_submit = clfs[i][1].predict(X_submit_scl)
    y_pred_submit = y_pred_submit.clip(min=0)
    y_pred_submit = y_pred_submit.clip(max=15)
    # pred_y = pred_y.astype(int)
    submission['DIH_' + str(clfs[i][0])] = y_pred_submit
    submission.groupby(['DIH_' + str(clfs[i][0])]).size()

submission.to_csv('../4.Evaluation/result.csv',index=False)
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 776 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=12)]: Done 1000 out of 1000 | elapsed:    0.5s finished
